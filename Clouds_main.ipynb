# %%
import xarray as xr
# Out:
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
from datetime import datetime
import numpy as n
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
plt.rcParams['figure.figsize'] = (10.0, 8)

# %%
plt.style.available
# Out:
# ['seaborn-muted',
#  'fast',
#  '_classic_test',
#  'seaborn-pastel',
#  'seaborn-colorblind',
#  'grayscale',
#  'seaborn-deep',
#  'seaborn-talk',
#  'tableau-colorblind10',
#  'seaborn-notebook',
#  'fivethirtyeight',
#  'seaborn-white',
#  'bmh',
#  'seaborn-dark',
#  'seaborn-bright',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'seaborn-whitegrid',
#  'Solarize_Light2',
#  'seaborn-poster',
#  'classic',
#  'seaborn-dark-palette',
#  'ggplot',
#  'seaborn-paper',
#  'seaborn',
#  'dark_background']

# %%
plt.style.use('seaborn-whitegrid')

# %%
#import cartopy # to check the correct environment

# %%
from netcdftime import utime
import datetime as datetime

# %%
import bisect
import numpy as np

# %%
filename3_ = '/home/ollie/muali/Data/Cloud_data2/shbclouds.19971020.19981001.cdf'
ds_cloud2 = xr.open_dataset(filename3_)

# %%
ds_cloud2
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 50112)
# Dimensions without coordinates: time
# Data variables:
#     dtime        (time) float32 ...
#     cldpresence  (time) int16 ...
#     oper_r       (time) int16 ...
#     oper_l       (time) int16 ...
#     lb_b         (time) float32 ...
#     lb_bt        (time) float32 ...
#     lb_e         (time) float32 ...
#     lb_et        (time) float32 ...
#     lb_ei        (time) int16 ...
#     lb_r         (time) float32 ...
#     lb_l         (time) float32 ...
#     ht_e         (time) float32 ...
#     ht_et        (time) float32 ...
#     ht_ei        (time) int16 ...
#     ht_r         (time) float32 ...
#     ht_l         (time) float32 ...
#     ct_r         (time) float32 ...
#     ct_l         (time) float32 ...
#     nl_m         (time) int16 ...
#     nl_i         (time) int16 ...
#     nl_r         (time) int16 ...
#     nl_l         (time) int16 ...
#     liqpresent   (time) int16 ...
#     liqheight    (time) float32 ...
#     liqtemp      (time) float32 ...
#     atten        (time) int16 ...
#     precip       (time) int16 ...
# Attributes:
#     file_created:       November 17, 2000
#     experiment:         Surface Heat Budget of the Arctic Ocean - SHEBA
#     file_coverage:      October 20, 1997 - October 1, 1998
#     file_description:   This file combines radar, lidar, and sounding measure...
#     radar_platform:     Merged radar cloud boundaries from the MMCR (Uttal)
#     lidar_platform:     Preliminary 10-min CLD files (layer averages) from DA...
#     sounding_platform:  Rawinsonde text files (Moritz), interpolated to time-...
#     radar_processing:   To degrade from 10-sec resolution, one radar beam is ...
#     flags:              Missing data values of -999 and -1 were used for floa...
#     note:               Any analysis utilizing these data should consider the...
#     lidar_note:         In the near future a gridded lidar data set will be p...
#     contact:            Matthew Shupe:  matthew.shupe@noaa.gov, 303-497-6471
#     organization:       NOAA, Environmental Technology Laboratory

# %%
#checking conversion from JDD to date-time
cdftime = utime('days since 1997-01-00 00:00:00') #defined wrt SHEBA wrt to days and not hours
#date = datetime.now()
#print (date)
#type(date)
t3 = 1 #jan 1,1997 is JD1 for Sheba
date3 = cdftime.num2date(t3)
print (date3)
# Out:
# 1997-01-01 00:00:00

# %% [markdown]
# Instead of converting every JDD time to datetime, just adding a time attribute should automatically make xarray intelligently load time

# %%
test = 293.96
cdftime.num2date(test)
# Out:
# datetime.datetime(1997, 10, 20, 23, 2, 24)

# %%
t_file = cdftime.num2date(ds_cloud2.dtime) # for converting into time
ds_cloud2.dtime.values = t_file
ds_cloud2.dtime # has 10 min time intervals
# Out:
# <xarray.DataArray 'dtime' (time: 50112)>
# array(['1997-10-20T00:00:00.000000000', '1997-10-20T00:10:01.171868000',
#        '1997-10-20T00:19:59.707024000', ..., '1998-10-02T23:30:01.757805000',
#        '1998-10-02T23:39:57.656243000', '1998-10-02T23:49:58.828118000'],
#       dtype='datetime64[ns]')
# Dimensions without coordinates: time
# Attributes:
#     long_name:  Day number, decimal
#     comment:    Calculated from 1/1/1997
#     interval:   10-minute

# %% [markdown]
# ## approach1

# %% [markdown]
# use slicing method in xarray

# %%
# filter values
ds_cloud2.lb_b.values[ds_cloud2.lb_b.values == -999] = np.nan

# %%
ds_cloud2['time'] = ds_cloud2.dtime

# %%
len(mask_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2fdabf46f61a> in <module>
# ----> 1 len(mask_time)
#
# NameError: name 'mask_time' is not defined

# %%
ds_cloud2.dtime
# Out:
# <xarray.DataArray 'dtime' (time: 50112)>
# array(['1997-10-20T00:00:00.000000000', '1997-10-20T00:10:01.171868000',
#        '1997-10-20T00:19:59.707024000', ..., '1998-10-02T23:30:01.757805000',
#        '1998-10-02T23:39:57.656243000', '1998-10-02T23:49:58.828118000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1997-10-20 ... 1998-10-02T23:49:58.828118
# Attributes:
#     long_name:  Day number, decimal
#     comment:    Calculated from 1/1/1997
#     interval:   10-minute

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-04', '1998-01-05 00:00'))
# Out:
# <xarray.DataArray 'lb_b' (time: 145)>
# array([0.105, 0.418, 0.448, 0.478, 0.478, 0.448, 0.448, 0.507, 0.507, 0.507,
#        0.478, 0.388, 0.448, 0.478, 0.105, 0.105, 0.478, 0.448, 0.478, 0.478,
#        0.418, 0.448, 0.418, 0.478, 0.508, 0.418, 0.388, 0.358, 0.298, 0.418,
#        0.239, 0.209, 0.239, 0.268, 0.298, 0.328, 0.298, 0.268, 0.328, 0.298,
#        0.268, 0.328, 0.328, 0.328, 0.388, 0.298, 0.298, 0.358, 0.388, 0.388,
#        0.358, 0.328, 0.298, 0.418, 0.478, 0.478, 0.448, 0.328, 0.507, 0.507,
#        0.537, 0.507, 0.507, 0.537, 0.627, 0.448, 0.448, 0.478, 0.537, 0.418,
#        0.537, 0.627, 0.657, 0.597, 0.657, 0.627, 0.597, 0.627, 0.627, 0.597,
#        0.627, 0.627, 0.627, 0.627, 0.657, 0.657, 0.627, 0.567, 0.567, 0.508,
#        0.448, 0.478, 0.268, 0.179, 0.179, 0.179, 0.105, 0.239, 0.105, 0.179,
#        0.105, 0.105, 0.105, 0.105, 0.358, 0.358, 0.358, 0.105, 0.105, 0.105,
#        0.105, 0.105, 0.105, 0.105, 0.105, 0.105, 0.105, 0.105, 0.105, 0.105,
#        0.105, 0.105, 0.105, 0.105, 0.105, 0.105, 1.075, 1.165, 1.314, 1.255,
#        1.285, 1.374, 0.388, 0.388, 0.388, 0.388, 0.328, 0.448, 0.448, 0.418,
#        0.478, 0.448, 0.105, 0.105, 0.105], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-04 ... 1998-01-05
# Attributes:
#     long_name:  Lowest cloud base height, best estimate
#     comment1:   Lidar base is used unless lidar was not operational
#     comment2:   When lidar inoperable, radar base may be biased low by precip...
#     units:      km AGL

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-04', '1998-01-05')).plot()

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-04-22:30', '1998-01-05 23:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.272596, dtype=float32)

# %% [markdown]
# Lowest cloud base for Jan 4 23:00 is 301 m

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-04-12:00', '1998-01-04 13:00')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.627, dtype=float32)

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-10-22:30', '1998-01-10 23:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.096429, dtype=float32)

# %% [markdown]
# Lowest cloud base for Jan 10th 23:00 is 102.9 m

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-12-10:30', '1998-01-12 11:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.110714, dtype=float32)

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-12-10:30', '1998-01-12 11:30')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(0.198429, dtype=float32)

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-10-22:30', '1998-01-10 23:30')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(0.542143, dtype=float32)

# %%
ds_cloud2.lb_b.sel(time=slice('1997-12-07-22:30', '1997-12-07 23:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.09, dtype=float32)

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-28-22:30', '1998-01-28 23:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.657, dtype=float32)

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-28-22:30', '1998-01-28 23:30')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(4.630714, dtype=float32)

# %% [markdown]
# LCB for 7th Dec 23:00 : 338.6 m

# %%
ds_cloud2.ht_e.sel(time=slice('1997-12-07-22:30', '1997-12-07 23:30')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(7.125, dtype=float32)

# %%
ds_cloud2.lb_b.sel(time=slice('1997-12-07-11:00', '1997-12-07 12:00')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.09, dtype=float32)

# %% [markdown]
# ## Cloud top

# %%
ds_cloud2.ht_e.values[ds_cloud2.ht_e.values == -999] =np.nan

# %%
ds_cloud2.ht_e
# Out:
# <xarray.DataArray 'ht_e' (time: 50112)>
# array([7.395, 7.395, 7.395, ..., 0.   , 0.   , 0.   ], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1997-10-20 ... 1998-10-02T23:49:58.828118
# Attributes:
#     long_name:  Highest return height (Highest cloud top, best estimate)
#     comment:    Highest return height measured by radar and lidar
#     units:      km AGL

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-04-22:30', '1998-01-04 23:30')).time
# Out:
# <xarray.DataArray 'time' (time: 7)>
# array(['1998-01-04T22:30:00.000000000', '1998-01-04T22:40:01.171868000',
#        '1998-01-04T22:49:59.707024000', '1998-01-04T23:00:00.878899000',
#        '1998-01-04T23:09:59.414055000', '1998-01-04T23:20:00.585930000',
#        '1998-01-04T23:29:59.121086000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-04T22:30:00 ... 1998-01-04T23:29:59.121086
# Attributes:
#     long_name:  Day number, decimal
#     comment:    Calculated from 1/1/1997
#     interval:   10-minute

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-04-22:30', '1998-01-04 23:30'))
# Out:
# <xarray.DataArray 'ht_e' (time: 7)>
# array([5.865, 6.045, 6.135, 6.225, 6.315, 6.225, 5.955], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-04T22:30:00 ... 1998-01-04T23:29:59.121086
# Attributes:
#     long_name:  Highest return height (Highest cloud top, best estimate)
#     comment:    Highest return height measured by radar and lidar
#     units:      km AGL

# %% [markdown]
# 1.67 km, 6.25 km

# %% [markdown]
# ## 4th Jan Plot

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-04', '1998-01-05')).plot(label='cloud top', c='b')
ds_cloud2.lb_b.sel(time=slice('1998-01-04', '1998-01-05')).plot(label='cloud base', c='r')
plt.legend()

# %% [markdown]
# Around 22:00 till 5th Jan 03:00 there is a high cloud top and thus the values looks consistent

# %% [markdown]
# ## 7th Dec Plot

# %%
ds_cloud2.ht_e.sel(time=slice('1997-12-07', '1997-12-08')).plot(label='cloud top', c='b')
ds_cloud2.lb_b.sel(time=slice('1997-12-07', '1997-12-08')).plot(label='cloud base', c='r') # lower base
plt.legend();

# %% [markdown]
# Consistently high cloud top during both the cloudy events on Dec 7th

# %% [markdown]
# ## 10th Jan

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-10', '1998-01-11')).plot(label='cloud top', c='b')
ds_cloud2.lb_b.sel(time=slice('1998-01-10', '1998-01-11')).plot(label='cloud base', c='r')
plt.legend();

# %% [markdown]
# Here the cloud top doesn't shoot high around the cloudy event of 10th Jan 23:00

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-12', '1998-01-13')).plot() # clear case
ds_cloud2.lb_b.sel(time=slice('1998-01-12', '1998-01-13')).plot() # lower base

# %% [markdown]
# Clear skies or ice clouds

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-12 10:30', '1998-01-12 11:30')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(0.198429, dtype=float32)

# %%
ds_cloud2.lb_b.sel(time=slice('1998-01-12 10:30', '1998-01-12 11:30')).mean()
# Out:
# <xarray.DataArray 'lb_b' ()>
# array(0.110714, dtype=float32)

# %%
ds_cloud2.ht_e.sel(time=('1998-01-04-22:10'))
# Out:
# <xarray.DataArray 'ht_e' (time: 1)>
# array([5.685], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1998-01-04T22:10:00.292961
# Attributes:
#     long_name:  Highest return height (Highest cloud top, best estimate)
#     comment:    Highest return height measured by radar and lidar
#     units:      km AGL

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-10-23:00', '1998-01-11 00:00')).mean()
# Out:
# <xarray.DataArray 'ht_e' ()>
# array(0.555, dtype=float32)

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-04-23:00', '1998-01-05 00:00')).mean()

# %%
ds_cloud2.ht_e.sel(time=slice('1998-01-04-23:00', '1998-01-05 00:00')).mean()

# %% [markdown]
# ## approach 2

# %% [markdown]
# Using bisect to bisect an array

# %%
# if the dates are sorted use bisect method, it's the fastest
lower = bisect.bisect_right(t_file, datetime.datetime(1998,1,3,23,50))
upper = bisect.bisect_left(t_file, datetime.datetime(1998,1,5,1))
mask_time = t_file [lower:upper]

# %%
mask_time
# Out:
# array([datetime.datetime(1998, 1, 4, 0, 0),
#        datetime.datetime(1998, 1, 4, 0, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 0, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 0, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 0, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 0, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 0, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 1, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 1, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 1, 30),
#        datetime.datetime(1998, 1, 4, 1, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 1, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 2, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 2, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 2, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 2, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 2, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 2, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 3, 0),
#        datetime.datetime(1998, 1, 4, 3, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 3, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 3, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 3, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 3, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 3, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 4, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 4, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 4, 30),
#        datetime.datetime(1998, 1, 4, 4, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 4, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 5, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 5, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 5, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 5, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 5, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 5, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 6, 0),
#        datetime.datetime(1998, 1, 4, 6, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 6, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 6, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 6, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 6, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 6, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 7, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 7, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 7, 30),
#        datetime.datetime(1998, 1, 4, 7, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 7, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 8, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 8, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 8, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 8, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 8, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 8, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 9, 0),
#        datetime.datetime(1998, 1, 4, 9, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 9, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 9, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 9, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 9, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 9, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 10, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 10, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 10, 30),
#        datetime.datetime(1998, 1, 4, 10, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 10, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 11, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 11, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 11, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 11, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 11, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 11, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 12, 0),
#        datetime.datetime(1998, 1, 4, 12, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 12, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 12, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 12, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 12, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 12, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 13, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 13, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 13, 30),
#        datetime.datetime(1998, 1, 4, 13, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 13, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 14, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 14, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 14, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 14, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 14, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 14, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 15, 0),
#        datetime.datetime(1998, 1, 4, 15, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 15, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 15, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 15, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 15, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 15, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 16, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 16, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 16, 30),
#        datetime.datetime(1998, 1, 4, 16, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 16, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 17, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 17, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 17, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 17, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 17, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 17, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 18, 0),
#        datetime.datetime(1998, 1, 4, 18, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 18, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 18, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 18, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 18, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 18, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 19, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 19, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 19, 30),
#        datetime.datetime(1998, 1, 4, 19, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 19, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 20, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 20, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 20, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 20, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 20, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 20, 49, 58, 828118),
#        datetime.datetime(1998, 1, 4, 21, 0),
#        datetime.datetime(1998, 1, 4, 21, 10, 1, 171868),
#        datetime.datetime(1998, 1, 4, 21, 19, 59, 707024),
#        datetime.datetime(1998, 1, 4, 21, 30, 0, 878899),
#        datetime.datetime(1998, 1, 4, 21, 39, 59, 414055),
#        datetime.datetime(1998, 1, 4, 21, 50, 0, 585930),
#        datetime.datetime(1998, 1, 4, 21, 59, 59, 121086),
#        datetime.datetime(1998, 1, 4, 22, 10, 0, 292961),
#        datetime.datetime(1998, 1, 4, 22, 19, 58, 828118),
#        datetime.datetime(1998, 1, 4, 22, 30),
#        datetime.datetime(1998, 1, 4, 22, 40, 1, 171868),
#        datetime.datetime(1998, 1, 4, 22, 49, 59, 707024),
#        datetime.datetime(1998, 1, 4, 23, 0, 0, 878899),
#        datetime.datetime(1998, 1, 4, 23, 9, 59, 414055),
#        datetime.datetime(1998, 1, 4, 23, 20, 0, 585930),
#        datetime.datetime(1998, 1, 4, 23, 29, 59, 121086),
#        datetime.datetime(1998, 1, 4, 23, 40, 0, 292961),
#        datetime.datetime(1998, 1, 4, 23, 49, 58, 828118),
#        datetime.datetime(1998, 1, 5, 0, 0),
#        datetime.datetime(1998, 1, 5, 0, 10, 1, 171868),
#        datetime.datetime(1998, 1, 5, 0, 19, 59, 707024),
#        datetime.datetime(1998, 1, 5, 0, 30, 0, 878899),
#        datetime.datetime(1998, 1, 5, 0, 39, 59, 414055),
#        datetime.datetime(1998, 1, 5, 0, 50, 0, 585930),
#        datetime.datetime(1998, 1, 5, 0, 59, 59, 121086)], dtype=object)

# %%
ds_cloud2.lb_b.values[ds_cloud2.lb_b.values == -999] = np.nan
ds_cloud2.lb_b[lower:upper].plot() # lowest cloud base height for 4th Jan in kms

# %%
ds_cloud2.ht_e
# Out:
# <xarray.DataArray 'ht_e' (time: 50112)>
# array([7.395, 7.395, 7.395, ..., 0.   , 0.   , 0.   ], dtype=float32)
# Dimensions without coordinates: time
# Attributes:
#     long_name:  Highest return height (Highest cloud top, best estimate)
#     comment:    Highest return height measured by radar and lidar
#     units:      km AGL

# %%
ds_cloud2.ht_e.values[ds_cloud2.ht_e.values == -999] = np.nan
ds_cloud2.ht_e[lower:upper].plot()
ds_cloud2.lb_b[lower:upper].plot() #plotted in green

# %%
mask_time[-1] # time goes till  hour ahead on the next day
# Out:
# datetime.datetime(1998, 1, 5, 0, 59, 59, 121086)

# %%
import seaborn as sns

# %% [markdown]
# # Plot of Cloud base vs Cloud Top

# %%
fig, ax = plt.subplots(figsize=(8,6),  dpi=100)
#y = ds_surf.lwp[lower:upper]
#x = np.arange(0,25,1)
ds_cloud2.lb_b[lower:upper].plot(c='red', label='Lowest Cloud Base')
ds_cloud2.ht_e[lower:upper].plot(c='blue', label='Cloud top')
#plt.plot(x,y)
#plt.title('Liquid water path on 4th Jan 1998')
ind = np.arange(0, 156, 24)
ax.set_xticks(ind)
ax.set_xticklabels(('0', '4', '8', '12', '16', '20', '24'))
plt.legend()
#ax.set_xlim(0,24)
ax.set_ylabel('AGL (km)')
ax.set_xlabel('Hours')
sns.despine(offset=10)
sns.set_style("ticks")

# %% [markdown]
# High cloud thickness during the time of sounding. Also, stratospheric clouds
#
# Find paper on extent of clouds during mixed phase events?
