# %% [markdown]
# Synoptic situation at SHEBa before the cases

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
plt.rcParams['figure.figsize'] = (10,8)

# %%
ds_sfc = xr.open_dataset('/home/ollie/muali/data_work/ERA/Surface/Surface_Jan_1_15.grib', engine='cfgrib')
ds_sfc
# Out:
# <xarray.Dataset>
# Dimensions:     (latitude: 241, longitude: 480, time: 60)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 1998-01-01 ... 1998-01-15T18:00:00
#     step        timedelta64[ns] ...
#     surface     int64 ...
#   * latitude    (latitude) float64 90.0 89.25 88.5 87.75 ... -88.5 -89.25 -90.0
#   * longitude   (longitude) float64 0.0 0.75 1.5 2.25 ... 357.8 358.5 359.2
#     valid_time  (time) datetime64[ns] ...
# Data variables:
#     u10         (time, latitude, longitude) float32 ...
#     v10         (time, latitude, longitude) float32 ...
#     t2m         (time, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     history:                 GRIB to CDM+CF via cfgrib-0.9.4.2/ecCodes-2.10.0...

# %%
ds_lvl = xr.open_dataset('/home/ollie/muali/data_work/ERA/Levels/Levels_Jan_1_15.grib', engine='cfgrib')
ds_lvl
# Out:
# <xarray.Dataset>
# Dimensions:        (isobaricInhPa: 13, latitude: 241, longitude: 480, time: 60)
# Coordinates:
#     number         int64 ...
#   * time           (time) datetime64[ns] 1998-01-01 ... 1998-01-15T18:00:00
#     step           timedelta64[ns] ...
#   * isobaricInhPa  (isobaricInhPa) int64 1000 925 900 875 ... 400 300 200 100
#   * latitude       (latitude) float64 90.0 89.25 88.5 ... -88.5 -89.25 -90.0
#   * longitude      (longitude) float64 0.0 0.75 1.5 2.25 ... 357.8 358.5 359.2
#     valid_time     (time) datetime64[ns] ...
# Data variables:
#     z              (time, isobaricInhPa, latitude, longitude) float32 ...
#     t              (time, isobaricInhPa, latitude, longitude) float32 ...
#     w              (time, isobaricInhPa, latitude, longitude) float32 ...
#     r              (time, isobaricInhPa, latitude, longitude) float32 ...
#     u              (time, isobaricInhPa, latitude, longitude) float32 ...
# ...

# %%
## Surface temperature

ds_sfc.t2m.sel(time='1998-01-04 18:00').plot()

# %%
ds_lvl.z.sel(isobaricInhPa=1000).sel(time='1998-01-04 00:00').plot();

# %%
ds_lvl.z.sel(isobaricInhPa=1000).sel(time='1998-01-04 12:00').plot();

# %%
ds_lvl.z.sel(isobaricInhPa=1000).sel(time='1998-01-04 18:00').plot();

# %%
ds_lvl.z.sel(isobaricInhPa=850).sel(time='1998-01-05 00:00').plot();

# %%
ds_lvl.to_netcdf('/home/ollie/muali/data_work/ERA/Levels/Levels_Jan_1_15.nc')

# %% [markdown]
# ## seaice quick plot

# %%
from mpl_toolkits.basemap import Basemap

# %%
d_seaice = xr.open_dataset('/home/ollie/muali/Data/G10010_SeaIce/G10010_SIBT1850_v1.1.nc')
d_seaice
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire(self)
#     136             try:
# --> 137                 file = self._cache[self._key]
#     138             except KeyError:
#
# /work/ollie/muali/miniconda3/envs/myenv1/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             move_to_end(self._cache, key)
#
# KeyError: [<function _open_scipy_netcdf at 0x7fae2a6a18c8>, ('/home/ollie/muali/Data/G10010_SeaIce/G10010_SIBT1850_v1.1.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...
